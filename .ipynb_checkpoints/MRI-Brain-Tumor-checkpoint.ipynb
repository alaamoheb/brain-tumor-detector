# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import random_split, Dataset, DataLoader, ConcatDataset
from torchvision import transforms, models
from torch.optim.lr_scheduler import StepLR
import glob
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score , confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import cv2
import sys
import random

# %% [markdown]
# reading & preprocessing data shapes

# %%
tumor = []
no_tumor = []

for i in glob.iglob('./data/brain_tumor_dataset/yes/*.jpg'):
    img = cv2.imread(i)
    img = cv2.resize(img, (128,128))
    b , g , r =cv2.split(img)
    img = cv2.merge([r, g , b])
    tumor.append(img)

# %%
for i in glob.iglob('./data/brain_tumor_dataset/no/*.jpg'):
    img = cv2.imread(i)
    img = cv2.resize(img, (128,128))
    b , g , r =cv2.split(img)
    img = cv2.merge([r, g , b])
    no_tumor.append(img)

# %%
for img in tumor:
    print(img.shape)
# Out:
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)

# %%
for img in no_tumor:
    print(img.shape)
# Out:
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)

# %%
no_tumor = np.array(no_tumor)
tumor = np.array(tumor)

# %%
tumor.shape
# Out:
# (154, 128, 128, 3)

# %%
no_tumor.shape
# Out:
# (91, 128, 128, 3)

# %%
all_data = np.concatenate((tumor,no_tumor))

# %%
all_data.shape
# Out:
# (245, 128, 128, 3)

# %%
np.random.choice(10, 5, replace=False)
# Out:
# array([3, 9, 6, 0, 1])

# %%
def plot_random(no_tumor, tumor, num=10):
    no_tumor_imgs = no_tumor[np.random.choice(no_tumor.shape[0], num, replace=False)]
    tumor_imgs = tumor[np.random.choice(tumor.shape[0], num, replace=False)]
    
    plt.figure(figsize=(16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('No Tumor')
        plt.imshow(no_tumor_imgs[i])
        
    plt.figure(figsize=(16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('Tumor')
        plt.imshow(tumor_imgs[i])

# %%
plot_random(no_tumor, tumor)

# %%
class Dataset(object):
    """An abstract class representing a Dataset.

    All other datasets should subclass it. All subclasses should override
    ``__len__``, that provides the size of the dataset, and ``__getitem__``,
    supporting integer indexing in range from 0 to len(self) exclusive.
    """

    def __getitem__(self, index):
        raise NotImplementedError

    def __len__(self):
        raise NotImplementedError

    def __add__(self, other):
        return ConcatDataset([self, other])

# %%
class MRI(Dataset):
    def __init__(self):
        
        tumor = []
        no_tumor = []
        for f in glob.iglob("./data/brain_tumor_dataset/yes/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1])) # to reshape to (#channels,h,w)
            tumor.append(img)

        for f in glob.iglob("./data/brain_tumor_dataset/no/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            no_tumor.append(img)

        #images
        tumor = np.array(tumor,dtype=np.float32)
        no_tumor = np.array(no_tumor,dtype=np.float32)
        #labels
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        no_tumor_label = np.zeros(no_tumor.shape[0], dtype=np.float32)
        #to concatenate
        self.images = np.concatenate((tumor, no_tumor), axis=0)
        self.labels = np.concatenate((tumor_label, no_tumor_label))
        
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, index):
        
        sample = {'image': self.images[index], 'label':self.labels[index]}
        
        return sample
    
    def normalize(self):
        self.images = self.images/255.0

# %%
mri_dataset = MRI()

train_size = int(0.8 * len(mri_dataset))
val_size = len(mri_dataset) - train_size

train_dataset, val_dataset = random_split(mri_dataset, [train_size, val_size])

# Create DataLoader instances
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# MODEL:

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.cnn_model = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5),
         nn.ReLU(),
        nn.AvgPool2d(kernel_size=2, stride=5),
        nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
        nn.ReLU(),
        nn.AvgPool2d(kernel_size=2, stride=5))
        
        self.fc_model = nn.Sequential(
        nn.Linear(in_features=256, out_features=120),
        nn.ReLU(),
        nn.Linear(in_features=120, out_features=84),
        nn.ReLU(),
        nn.Linear(in_features=84, out_features=1))
        
    def forward(self, x):
        x = self.cnn_model(x)
        x = x.view(x.size(0), -1)
        x = self.fc_model(x)
        x = F.sigmoid(x)
        
        return x

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = CNN().to(device)

criterion = nn.BCELoss()  # Binary Cross-Entropy loss
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)  # Learning rate scheduler

# %%
epochs = 50
# Early Stopping Variables
best_val_loss = np.inf  # Start with an infinitely large value
patience = 5  # Number of epochs with no improvement before stopping
patience_counter = 0  # Counter for epochs without improvement

# Training Loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    running_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    for D in train_loader:
        images = D['image'].to(device)
        labels = D['label'].to(device).float()

        optimizer.zero_grad()
        outputs = model(images).squeeze()
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        predicted = (outputs >= 0.5).float()  # Binary threshold for predictions
        correct_predictions += (predicted == labels).sum().item()
        total_samples += labels.size(0)

    # Compute training loss and accuracy
    train_loss = running_loss / len(train_loader)
    train_accuracy = correct_predictions / total_samples


    
    model.eval()
    val_loss = 0.0
    correct_val_predictions = 0
    total_val_samples = 0

    with torch.no_grad():
        for D in val_loader:  # Assuming a validation loader
            images = D['image'].to(device)
            labels = D['label'].to(device).float()

            outputs = model(images).squeeze()
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            
# Epoch 25/50, Train Loss: 0.0028, Train Accuracy: 1.0000, Validation Loss: 0.8335, Validation Accuracy: 0.8163
# Epoch 26/50, Train Loss: 0.0021, Train Accuracy: 1.0000, Validation Loss: 0.8032, Validation Accuracy: 0.8367
# Epoch 27/50, Train Loss: 0.0023, Train Accuracy: 1.0000, Validation Loss: 0.8063, Validation Accuracy: 0.8367
# Epoch 28/50, Train Loss: 0.0014, Train Accuracy: 1.0000, Validation Loss: 0.8090, Validation Accuracy: 0.8367
# Epoch 29/50, Train Loss: 0.0011, Train Accuracy: 1.0000, Validation Loss: 0.8452, Validation Accuracy: 0.8367
# Epoch 30/50, Train Loss: 0.0010, Train Accuracy: 1.0000, Validation Loss: 0.8596, Validation Accuracy: 0.8367
# Epoch 31/50, Train Loss: 0.0010, Train Accuracy: 1.0000, Validation Loss: 0.8478, Validation Accuracy: 0.8367
# Epoch 32/50, Train Loss: 0.0008, Train Accuracy: 1.0000, Validation Loss: 0.8513, Validation Accuracy: 0.8367
# Epoch 33/50, Train Loss: 0.0006, Train Accuracy: 1.0000, Validation Loss: 0.8555, Validation Accuracy: 0.8367
# Epoch 34/50, Train Loss: 0.0009, Train Accuracy: 1.0000, Validation Loss: 0.8609, Validation Accuracy: 0.8367
# Epoch 35/50, Train Loss: 0.0005, Train Accuracy: 1.0000, Validation Loss: 0.8647, Validation Accuracy: 0.8367
# Epoch 36/50, Train Loss: 0.0005, Train Accuracy: 1.0000, Validation Loss: 0.8727, Validation Accuracy: 0.8367
# Epoch 37/50, Train Loss: 0.0005, Train Accuracy: 1.0000, Validation Loss: 0.8838, Validation Accuracy: 0.8367
# Epoch 38/50, Train Loss: 0.0004, Train Accuracy: 1.0000, Validation Loss: 0.9051, Validation Accuracy: 0.8367
# Epoch 39/50, Train Loss: 0.0004, Train Accuracy: 1.0000, Validation Loss: 0.9069, Validation Accuracy: 0.8367
# Epoch 40/50, Train Loss: 0.0004, Train Accuracy: 1.0000, Validation Loss: 0.9035, Validation Accuracy: 0.8367
# Epoch 41/50, Train Loss: 0.0006, Train Accuracy: 1.0000, Validation Loss: 0.9232, Validation Accuracy: 0.8367
# Epoch 42/50, Train Loss: 0.0004, Train Accuracy: 1.0000, Validation Loss: 0.9461, Validation Accuracy: 0.8163
# Epoch 43/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Validation Loss: 0.9205, Validation Accuracy: 0.8367
# Epoch 44/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Validation Loss: 0.8977, Validation Accuracy: 0.8367
# Epoch 45/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Validation Loss: 0.8966, Validation Accuracy: 0.8367
# Epoch 46/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Validation Loss: 0.9191, Validation Accuracy: 0.8367
# Epoch 47/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Validation Loss: 0.9418, Validation Accuracy: 0.8367
# Epoch 48/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Validation Loss: 2.2656, Validation Accuracy: 0.8367
# Epoch 49/50, Train Loss: 0.0002, Train Accuracy: 1.0000, Validation Loss: 2.2710, Validation Accuracy: 0.8367
# Epoch 50/50, Train Loss: 0.0003, Train Accuracy: 1.0000, Validation Loss: 2.2706, Validation Accuracy: 0.8367

# %%
# Plot Loss
plt.figure(figsize=(12, 6))
plt.plot(range(1, epochs + 1), train_losses, label="Train Loss")
plt.plot(range(1, epochs + 1), val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(range(1, epochs + 1), train_accuracies, label="Train Accuracy")
plt.plot(range(1, epochs + 1), val_accuracies, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()
plt.show()

# %%
model.eval()
outputs = []
y_true = []

with torch.no_grad():
    for D in train_loader:
        image = D['image'].to(device)
        label = D['label'].to(device)

        y_hat = model(image)

        # Collect the outputs and labels
        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())

# Flatten the list of outputs and labels
outputs = np.concatenate(outputs)
y_true = np.concatenate(y_true)

# Calculate the predictions by applying a threshold (0.5 for binary classification)
predictions = (outputs >= 0.5).astype(np.float32)

# Calculate accuracy
accuracy = accuracy_score(y_true, predictions)
print(f"Validation Accuracy: {accuracy:.4f}")

# Optionally save the model
torch.save(model.state_dict(), 'brain_tumor_model.pth')
print("Model saved successfully!")
# Out:
# Validation Accuracy: 1.0000
# Model saved successfully!

# %%
conf_matrix = confusion_matrix(y_true, predictions)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=["No Tumor", "Tumor"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# Print confusion matrix values
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 75   0]
#  [  0 121]]
